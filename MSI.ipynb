# %% [markdown]
# # Minority Serving Institutions Present in Affiliation Data
#
# * The fuzzy matching pipeline below was developed to discern the associations between authors and specific Minority Serving Institutions (MSIs).

# %%
from fuzzywuzzy import fuzz

# %%
import pandas as pd
import numpy as np

# %%
# author affiliation data for the compare and control datasets
controlData = pd.read_csv("GuruData/control_group_affils(7).csv", encoding='utf-8')
compareData = pd.read_csv("GuruData/mimic_affils(7).csv", encoding='utf-8')

# below are the datasets containing Minority Serving Institutions for the year 2020 and 2022
minorityList2020 = pd.read_csv("GuruData/2020_Minority_Serving_Institutions-1.csv")
minorityList2022 = pd.read_csv("GuruData/2022 CMSI Eligibility Matrix .csv")

# %%
# Out:
# (25676, 19)

# %%
controlData.head()
# Out:
#    Unnamed: 0 aff_city  aff_city_id aff_country aff_country_code  \
# 0           6   Leuven    2792482.0     Belgium               BE
# 1           7   Leuven    2792482.0     Belgium               BE
# 2           8   Leuven    2792482.0     Belgium               BE
# 3           9   Leuven    2792482.0     Belgium               BE
# 4          10   Leuven    2792482.0     Belgium               BE
#
#           aff_id                                 aff_name  \
# 0  grid.15762.37                                     Imec
# 1  grid.15762.37                                     Imec
# 2  grid.15762.37                                     Imec
# 3            NaN  Independent Consultant, Leuven, Belgium
# 4  grid.15762.37                                     Imec
#
#                           aff_raw_affiliation aff_state aff_state_code  \
# 0  Exascience Life Lab, imec, Leuven, Belgium       NaN            NaN
# 1  Exascience Life Lab, imec, Leuven, Belgium       NaN            NaN
# 2  Exascience Life Lab, imec, Leuven, Belgium       NaN            NaN
# 3     Independent Consultant, Leuven, Belgium  Flanders            NaN
# 4  Exascience Life Lab, imec, Leuven, Belgium       NaN            NaN
#
#            pub_id       researcher_id first_name last_name  year  gender  \
# 0  pub.1153863516  ur.015256430001.18      Ellie   D’Hondt  2022  female
# 1  pub.1153863516  ur.010363506743.89  Thomas J.     Ashby  2022    male
# 2  pub.1153863516  ur.012727306525.02       Imen  Chakroun  2022  female
# 3  pub.1153863516                 NaN     Thomas  Koninckx  2022    male
# 4  pub.1153863516  ur.012704525025.77       Roel     Wuyts  2022    male
#
#    gender_ints income_class  income_class_num
# 0          1.0  High income               4.0
# 1          0.0  High income               4.0
# 2          1.0  High income               4.0
# 3          0.0  High income               4.0
# 4          0.0  High income               4.0

# %%
controlData.shape[0]
# Out:
# 25676

# %%
compareData.head()
# Out:
#    Unnamed: 0   aff_city  aff_city_id aff_country aff_country_code  \
# 0           0  Guangzhou    1809858.0       China               CN
# 1           1  Guangzhou    1809858.0       China               CN
# 2           2  Guangzhou    1809858.0       China               CN
# 3           3  Guangzhou    1809858.0       China               CN
# 4           4  Guangzhou    1809858.0       China               CN
#
#           aff_id                                       aff_name  \
# 0  grid.412601.0  First Affiliated Hospital of Jinan University
# 1  grid.412601.0  First Affiliated Hospital of Jinan University
# 2  grid.412601.0  First Affiliated Hospital of Jinan University
# 3  grid.412601.0  First Affiliated Hospital of Jinan University
# 4  grid.412601.0  First Affiliated Hospital of Jinan University
#
#                                  aff_raw_affiliation aff_state aff_state_code  \
# 0  Department of Neurology, The First Affiliated ...       NaN            NaN
# 1  Department of Neurology, The First Affiliated ...       NaN            NaN
# 2  Department of Neurology, The First Affiliated ...       NaN            NaN
# 3  Department of Neurology, The First Affiliated ...       NaN            NaN
# 4  Department of Clinical Research, The First Aff...       NaN            NaN
#
#            pub_id       researcher_id first_name last_name  year  gender  \
# 0  pub.1154144039  ur.014116573320.23    Xiaxuan     Huang  2022    male
# 1  pub.1154144039  ur.016241001520.36      Shiqi      Yuan  2022  female
# 2  pub.1154144039  ur.013553641416.27     Yitong      Ling  2022  female
# 3  pub.1154144039  ur.014351222016.81   Shanyuan       Tan  2022  female
# 4  pub.1154144039  ur.014227217615.79        Tao     Huang  2022    male
#
#    gender_ints         income_class  income_class_num
# 0          0.0  Upper middle income               3.0
# 1          1.0  Upper middle income               3.0
# 2          1.0  Upper middle income               3.0
# 3          1.0  Upper middle income               3.0
# 4          0.0  Upper middle income               3.0

# %%
compareData.shape[0]
# Out:
# 13967

# %%
minorityList2020.head()
# Out:
#         MSI Type                     Institution  Unnamed: 2       City  \
# 0           ANNH  University of Alaska Fairbanks         NaN  Fairbanks
# 1           ANNH  University of Alaska Southeast         NaN     Juneau
# 2  ANNH & NASNTI        Alaska Christian College         NaN   Soldotna
# 3         NASNTI       Alaska Pacific University         NaN  Anchorage
# 4            TCU               Ilisagvik College         NaN     Barrow
#
#   State/Territory     Type
# 0              AK  Pub 4yr
# 1              AK  Pub 4yr
# 2              AK  Pri 2yr
# 3              AK  Pri 4yr
# 4              AK  Pub 4yr

# %%
# dropping all the NA values
minorityList2022['Institution Name'].dropna()
# Out:
# 0              Aaniiih Nakoda College
# 1              Adams State University
# 2                  Adelphi University
# 3             AdventHealth University
# 4            Alabama A & M University
#                     ...
# 858        Woodland Community College
# 859          World Mission University
# 860          World Mission University
# 861    Xavier University of Louisiana
# 862             Yakima Valley College
# Name: Institution Name, Length: 863, dtype: object

# %%
def isfloat(num):
    try:
        float(num)
        return True
    except ValueError:
        return False

# %%
msi = []

# compiling MSI type information for the 2022 list
for i in range(865):
        if(isfloat(minorityList2022.loc[i]['ANNH']) == False and minorityList2022.loc[i]['ANNH'] == 'Yes'):
            msi.append('ANNH')
        elif(isfloat(minorityList2022.loc[i]['AANAPISI']) == False and minorityList2022.loc[i]['AANAPISI'] == 'Yes'):
            msi.append('AANAPISI')
        elif(isfloat(minorityList2022.loc[i]['HSI']) == False and minorityList2022.loc[i]['HSI'] == 'Yes'):
            msi.append('HSI')
        elif(isfloat(minorityList2022.loc[i]['NASNTI']) == False and minorityList2022.loc[i]['NASNTI'] == 'Yes'):
            msi.append('NASNTI')
        elif(isfloat(minorityList2022.loc[i]['PBI']) == False and minorityList2022.loc[i]['PBI'] == 'Yes'):
            msi.append('PBI')
        elif(isfloat(minorityList2022.loc[i]['HBCU']) == False and minorityList2022.loc[i]['HBCU'] == 'Yes'):
            msi.append('HBCU')
        elif(isfloat(minorityList2022.loc[i]['TCU']) == False and minorityList2022.loc[i]['TCU'] == 'Yes'):
            msi.append('TCU')
        else:
            msi.append('No MSI Type')

# %%
#appending the MSI type information to the 2022 file
minorityList2022['MSI Type'] = msi

# %%
#understanding the number of unique institutions (non-exact matches) in each respective file
uniqueInstitutions = set(minorityList2020['Institution']).intersection(set(minorityList2022['Institution Name']))
print(uniqueInstitutions)
# Out:
# {'CUNY Hunter College', 'SUNY Westchester Community College', 'Trinity Washington University', 'Metropolitan State University of Denver', 'Heritage University', 'Laney College', 'Seminole State College of Florida', 'University of Guam', 'Cossatot Community College of the University of Arkansas', 'East Los Angeles College', 'Aurora University', 'Nevada State College', 'Rogers State University', 'Palomar College', 'University of North Carolina at Pembroke', 'Hope International University', 'Pacific Islands University', 'Antelope Valley College', 'Whittier College', 'Century College', 'University of North Texas at Dallas', 'Cisco College', 'Mercy College', 'South Plains College', 'Texas State Technical College', 'Georgia State University', 'Nova Southeastern University', 'Fisk University', 'McMurry University', 'Belhaven University', 'Modesto Junior College', 'Southwestern Christian College', 'Winston-Salem State University', 'Leech Lake Tribal College', 'El Paso Community College', 'Las Positas College', 'Windward Community College', 'Livingstone College', 'Los Angeles Valley College', 'Bergen Community College', 'Vernon College', 'Augusta Technical College', 'Community College of Philadelphia', 'Phoenix College', 'South Louisiana Community College', 'Claflin University', "Mount Saint Mary's University", 'Hinds Community College', 'Arkansas State University Mid-South', 'Rust College', 'Miles College', 'Bishop State Community College', 'Georgia Military College', 'American University of Puerto Rico', 'Norwalk Community College', "Saint Augustine's University", 'Sul Ross State University', 'Golden West College', 'Orange Coast College', 'Texas Lutheran University', 'Valencia College', 'Passaic County Community College', 'Notre Dame de Namur University', 'South Carolina State University', 'Morgan State University', 'College of the Mainland', 'Northeastern Illinois University', 'Philander Smith College', 'Community College of Aurora', 'Hawaii Pacific University', 'North Hennepin Community College', 'Mississippi Delta Community College', 'Grambling State University', 'CUNY Medgar Evers College', 'Northern Virginia Community College', "Saint Mary's College of California", 'Solano Community College', 'GateWay Community College', 'Pasadena City College', 'North Carolina Central University', 'Amarillo College', 'Brazosport College', 'Paine College', 'Coppin State University', 'Gavilan College', 'Houston Baptist University', 'Fort Valley State University', 'Laredo College', "Tohono O'odham Community College", 'Bloomfield College', 'New York College of Health Professions', 'Dine College', 'Sinte Gleska University', 'Barry University', 'Texas Southmost College', 'College of Lake County', 'CUNY York College', 'Blue Mountain Community College', 'Metropolitan College of New York', 'Monterey Peninsula College', 'Treasure Valley Community College', 'Dillard University', 'Azusa Pacific University', 'New Jersey City University', 'Montclair State University', 'Langston University', 'Holy Names University', 'McLennan Community College', 'Chaminade University of Honolulu', 'Lone Star College System', 'Cypress College', 'Pueblo Community College', 'Universidad Central de Bayamon', 'Los Angeles City College', 'Dominican University', 'Howard University', 'Southwestern Indian Polytechnic Institute', 'Virginia University of Lynchburg', 'Los Angeles Mission College', 'Southeastern Oklahoma State University', 'Elizabeth City State University', 'Los Angeles Pierce College', 'CUNY LaGuardia Community College', 'University of the Incarnate Word', 'Halifax Community College', 'Shorter College', 'Palm Beach State College', 'Georgia Gwinnett College', 'Lane College', 'Bluefield State College', 'Salish Kootenai College', 'Denmark Technical College', 'Kapiolani Community College', 'Gateway Community College', 'Nebraska Indian Community College', 'Del Mar College', 'Sacramento City College', 'San Joaquin Delta College', 'Chowan University', 'Houston Community College ...

# %%
minorityList2020['Institution'].isin(minorityList2022['Institution Name']).value_counts()
# Out:
# True     495
# False    279
# Name: Institution, dtype: int64

# %%
minorityList2022['Institution Name'].isin(minorityList2020['Institution']).value_counts()
# Out:
# True     496
# False    369
# Name: Institution Name, dtype: int64

# %%
minorityList2020.shape[0]
# Out:
# 774

# %%
minorityList2022.shape[0]
# Out:
# 865

# %% [markdown]
# ### MSI List Similiarity Analysis (2020 vs 2022):
# * A total of 496 institutions were shared by the two sources (exact matches)
#     * Some more institutions are shared but their institution name is formatted differently

# %% [markdown]
# ### Using fuzzy match (threshold value of 97) percent to guage a more accurate approximation

# %%
def matchMSIFuzzy(x):
    for i in range(862):
        if(isfloat(x) == False and fuzz.partial_ratio(minorityList2022.loc[i]['Institution Name'], x) > 97):
            return "Yes"
    return "No"

# %%
minorityList2020['isIn2022'] = minorityList2020['Institution'].apply(matchMSIFuzzy)

# %%
minorityList2020['isIn2022'].value_counts()
# Out:
# Yes    566
# No     208
# Name: isIn2022, dtype: int64

# %% [markdown]
# ### MSI List Similiarity Analysis w/ Fuzzy Match (2020 vs 2022):
# * A total of 566 institutions were shared by the two sources

# %%
# dropping all the affiliation data that doesn't originate within the United States or has no country affilation
comparI = compareData[compareData['aff_country'] != 'United States'].index
compareData = compareData.drop(comparI)
controlI = controlData[controlData['aff_country'] != 'United States'].index
controlData = controlData.drop(controlI)
compareData['aff_country'].dropna()
controlData['aff_country'].dropna()
# Out:
# 6        United States
# 38       United States
# 39       United States
# 40       United States
# 41       United States
#              ...
# 25660    United States
# 25661    United States
# 25662    United States
# 25663    United States
# 25664    United States
# Name: aff_country, Length: 7654, dtype: object

# %% [markdown]
# ### Fuzzy Matching Affiliation Data for Compare and Control Groups with MSI Lists

# %%
# fuzzy matching methods for both 2020 and 2022 lists

def fuzzTest(x):
    for i in range(774):
        if(isfloat(x) == False and fuzz.partial_ratio(minorityList2020.loc[i]['Institution'], x) > 97):
            return minorityList2020.loc[i]['Institution']
    return "Not Minority"

def fuzzTest2(x):
    for i in range(862):
        if(isfloat(x) == False and fuzz.partial_ratio(minorityList2022.loc[i]['Institution Name'], x) > 97):
            return minorityList2022.loc[i]['Institution Name']
    return "Not Minority"

# %%
# applying the method to the affiliation name column
compareData['isMinority_2020'] = compareData['aff_name'].apply(fuzzTest)
controlData['isMinority_2020'] = controlData['aff_name'].apply(fuzzTest)
compareData['isMinority_2022'] = compareData['aff_name'].apply(fuzzTest2)
controlData['isMinority_2022'] = controlData['aff_name'].apply(fuzzTest2)

# %%
#understanding the distributions of the values

# %%
compareData['isMinority_2020'].value_counts()
# Out:
# Not Minority                                                3370
# University of Washington - Seattle                            70
# Cheyney University of Pennsylvania                            59
# University of Minnesota - Twin Cities                         41
# Arizona State University                                      24
# Vanguard University of Southern California                    16
# University of California, Irvine                              12
# University of Illinois at Chicago                              8
# Texas A&M University - Corpus Christi                          8
# University of Connecticut - Hartford Campus                    7
# Colorado State University - Pueblo                             7
# University of Texas at Arlington                               6
# University of Arizona (The)                                    6
# Winston-Salem State University                                 5
# Rutgers, the State University of New Jersey                    5
# Florida International University                               4
# Pennsylvania State University - Penn State Abington            4
# University of Houston                                          4
# University of California, Davis                                3
# University of New Mexico                                       1
# Howard University                                              1
# Georgia State University                                       1
# University of California, Santa Cruz                           1
# CUNY Borough of Manhattan Community College                    1
# University of Central Florida                                  1
# University of California, Riverside                            1
# California State University, Northridge                        1
# Texas Tech University                                          1
# University of Texas Health Science Center at San Antonio       1
# University of California, Santa Barbara                        1
# Name: isMinority_2020, dtype: int64

# %%
compareMinorityValues2020 = compareData['isMinority_2020'].value_counts().to_frame()

# %%
controlData['isMinority_2020'].value_counts()
# Out:
# Not Minority                                                              7031
# Cheyney University of Pennsylvania                                         173
# Vanguard University of Southern California                                  87
# University of Washington - Seattle                                          77
# University of Minnesota - Twin Cities                                       40
# University of Arizona (The)                                                 39
# University of California, Davis                                             34
# University of California, Irvine                                            28
# University of Texas Health Science Center at San Antonio                    27
# University of Connecticut - Hartford Campus                                 14
# Rutgers, the State University of New Jersey                                 13
# Pennsylvania State University - Penn State Abington                         11
# Georgia State University                                                    10
# University of Illinois at Chicago                                            9
# Texas Tech University                                                        9
# University of Central Florida                                                6
# Texas A&M University - Corpus Christi                                        6
# San Diego State University                                                   5
# University of New Mexico                                                     5
# University of Houston                                                        5
# University of Texas at San Antonio                                           4
# Arizona State University                                                     4
# University of Texas at Arlington                                             3
# Tennessee State University                                                   2
# Colorado State University - Pueblo                                           2
# Florida Atlantic University                                                  2
# University of California, Riverside                                          2
# City College                                                                 1
# Florida International University                                             1
# California State University, San Bernardino                                  1
# New York City College of Technology of the City University of New York       1
# University of California, Santa Barbara                                      1
# CUNY Hunter College                                                          1
# Name: isMinority_2020, dtype: int64

# %%
controlMinorityValues2020 = controlData['isMinority_2020'].value_counts().to_frame()

# %%
compareData['isMinority_2022'].value_counts()
# Out:
# Not Minority                                                    3377
# University of Washington-Tacoma Campus                            70
# Cheyney University of Pennsylvania                                59
# The University of Texas at Austin                                 44
# University of Minnesota-Morris                                    41
# Vanguard University of Southern California                        16
# Texas A&M University-Central Texas                                 8
# University of Connecticut-Hartford Campus                          7
# Colorado State University Pueblo                                   7
# University of Arizona                                              6
# The University of Texas at Arlington                               6
# Winston-Salem State University                                     5
# University of Houston                                              4
# Loma Linda University                                              4
# Florida International University                                   4
# St. John's University-New York                                     3
# CUNY Borough of Manhattan Community College                        1
# University of Central Florida                                      1
# Georgia State University                                           1
# University of New Mexico-Gallup Campus                             1
# Louisiana State University-Alexandria                              1
# Meharry Medical College                                            1
# The University of Texas Health Science Center at San Antonio       1
# Texas Tech University                                              1
# Howard University                                                  1
# Name: isMinority_2022, dtype: int64

# %%
compareMinorityValues2022 = compareData['isMinority_2022'].value_counts().to_frame()

# %%
controlData['isMinority_2022'].value_counts()
# Out:
# Not Minority                                                    7062
# Cheyney University of Pennsylvania                               173
# Vanguard University of Southern California                        87
# University of Washington-Tacoma Campus                            77
# University of Minnesota-Morris                                    40
# University of Arizona                                             39
# The University of Texas at Austin                                 25
# Wayne State University                                            23
# The University of Texas Health Science Center at San Antonio      18
# University of Connecticut-Hartford Campus                         14
# Georgia State University                                          10
# Texas Tech University                                              9
# Virginia Commonwealth University                                   8
# Loma Linda University                                              7
# California Polytechnic State University-San Luis Obispo            6
# University of Central Florida                                      6
# Northern Arizona University                                        6
# Texas A&M University-Central Texas                                 6
# University of Houston                                              5
# University of New Mexico-Gallup Campus                             5
# San Diego State University                                         5
# The University of Texas at San Antonio                             4
# The University of Texas at Arlington                               3
# Florida Atlantic University                                        2
# The University of Texas Rio Grande Valley                          2
# Colorado State University Pueblo                                   2
# Tennessee State University                                         2
# University of North Texas                                          1
# Indiana University-Northwest                                       1
# St. John's University-New York                                     1
# Morehouse School of Medicine                                       1
# Auburn University at Montgomery                                    1
# New Mexico Institute of Mining and Technology                      1
# CUNY Hunter College                                                1
# Florida International University                                   1
# Name: isMinority_2022, dtype: int64

# %%
controlMinorityValues2022 = controlData['isMinority_2022'].value_counts().to_frame()

# %% [markdown]
# ### Understanding MSI types
# * The OIC supports colleges and universities designated as minority serving institutions:
#
#     * Asian American Native American Pacific Islander-Serving Institutions (ANNAPISIs)
#     * Alaska Native and Native Hawaiian Serving Institutions (ANNHs)
#     * Historically Black Colleges & Universities (HBCUs)
#     * Hispanic Serving institutions (HSIs)
#     * Native American-Serving Non-Tribal Institutions (NASNTIs)
#     * Predominantly Black Institutions (PBIs)
#     * Tribal Colleges and Universities (TCUs)

# %%
# Type
def typeInfo(x):
    if (x != 'Not Minority'):
        indexArray = minorityList2020[minorityList2020['Institution']== x].index.values
        index = indexArray[0]
        return minorityList2020.loc[index]['Type']
    return 'Not Minority'
def typeInfo2(x):
    if (x != 'Not Minority'):
        indexArray = minorityList2022[minorityList2022['Institution Name']== x].index.values
        index = indexArray[0]
        return minorityList2022.loc[index]['Type']
    return 'Not Minority'

# %%
compareData['Type2020'] = compareData['isMinority_2020'].apply(typeInfo)
controlData['Type2020'] = controlData['isMinority_2020'].apply(typeInfo)
compareData['Type2022'] = compareData['isMinority_2022'].apply(typeInfo2)
controlData['Type2022'] = controlData['isMinority_2022'].apply(typeInfo2)

# %%
# MSI Type
def msiInfo(x):
    if (x != 'Not Minority'):
        indexArray = minorityList2020[minorityList2020['Institution'] == x].index.values
        index = indexArray[0]
        return minorityList2020.loc[index]['MSI Type']
    return 'Not Minority'
def msiInfo2(x):
    if (x != 'Not Minority'):
        indexArray = minorityList2022[minorityList2022['Institution Name'] == x].index.values
        index = indexArray[0]
        return minorityList2022.loc[index]['MSI Type']
    return 'Not Minority'

# %%
compareData['MSI Type2020'] = compareData['isMinority_2020'].apply(msiInfo)
controlData['MSI Type2020'] = controlData['isMinority_2020'].apply(msiInfo)
compareData['MSI Type2022'] = compareData['isMinority_2022'].apply(msiInfo2)
controlData['MSI Type2022'] = controlData['isMinority_2022'].apply(msiInfo2)

# %%
compareData['MSI Type2020'].value_counts()
# Out:
# Not Minority      3370
# AANAPISI           125
# HSI                 79
# HBCU                65
# AANAPISI & HSI      30
# AANAPISI & PBI       1
# Name: MSI Type2020, dtype: int64

# %%
controlData['MSI Type2020'].value_counts()
# Out:
# Not Minority      7031
# HSI                198
# AANAPISI           176
# HBCU               175
# AANAPISI & HSI      63
# AANAPISI & PBI      10
# PBI                  1
# Name: MSI Type2020, dtype: int64

# %%
compareData['MSI Type2022'].value_counts()
# Out:
# Not Minority    3377
# AANAPISI         139
# HBCU              66
# HSI               46
# NASNTI            42
# Name: MSI Type2022, dtype: int64

# %%
controlData['MSI Type2022'].value_counts()
# Out:
# Not Minority    7062
# HSI              190
# AANAPISI         185
# HBCU             176
# NASNTI            40
# PBI                1
# Name: MSI Type2022, dtype: int64

# %% [markdown]
# ### Cleaning Process
# * To confirm the accuracy of the mapping between institutional affiliations and their potential MSI status, we performed manual verification on a subset of the results yielded by the aforementioned fuzzy-matching process. In cases when an author’s institutional affiliation was incorrectly mapped to an MSI, we rectified the mistake manually. Verification was limited to reducing false positives, i.e., we only determined institutional affiliations that were erroneously linked with MSIs.
# * This allowed us to understand which MSIs appeared in the datasets
#     * Used this information in gender and first vs last author pipelines

# %% [markdown]
# # Gender Distributions of Authors Affiliated w/ MSIs

# %%
remControl = pd.read_csv("/Users/gurucharanlingamallu/Downloads/controlUnionType.xlsx - Sheet 1 - controlUnion.csv")
remMIMIC = pd.read_csv("/Users/gurucharanlingamallu/Downloads/mimicUnionType.xlsx - Sheet 1 - mimicUnion.csv")
mimic20 = pd.read_csv("/Users/gurucharanlingamallu/Documents/MIT Work/minorityMimicCorrectX(d).csv")
mimic22 = pd.read_csv("/Users/gurucharanlingamallu/Documents/MIT Work/minorityMimicCorrectX(d).csv")
control20 = pd.read_csv("/Users/gurucharanlingamallu/Documents/MIT Work/minorityContolCorrectX(d).csv")
control22 = pd.read_csv("/Users/gurucharanlingamallu/Documents/MIT Work/minorityContolCorrectX(d).csv")
mimicAffils = pd.read_csv("/Users/gurucharanlingamallu/Downloads/mimic_affils(7).csv")
controlAffils = pd.read_csv("/Users/gurucharanlingamallu/Downloads/control_group_affils(7).csv")
controlGender = pd.read_csv("/Users/gurucharanlingamallu/Downloads/control_group_affils_v2.csv")

# %% [markdown]
# ##### following is for cleaning the datasets

# %%
def filter_rows_by_values(df, col, values):
    return df[~df[col].isin(valuexs)]

# %%
remControl.head()
# Out:
#    controlUnion                             Unnamed: 1        Unnamed: 2  \
# 0           NaN                            Institution  isMinority_Union
# 1           0.0                           Not Minority              7750
# 2           1.0     University of Washington - Seattle                66
# 3           2.0  University of Minnesota - Twin Cities                48
# 4           3.0      The University of Texas at Austin                35
#
#     Unnamed: 3
# 0     MSI_Type
# 1  No MSI Type
# 2     AANAPISI
# 3     AANAPISI
# 4     AANAPISI

# %%
remMIMIC.head()
# Out:
#    mimicUnion                             Unnamed: 1        Unnamed: 2  \
# 0         NaN                            Institution  isMinority_Union
# 1         0.0                           Not Minority              3395
# 2         1.0     University of Washington - Seattle                70
# 3         2.0  University of Minnesota - Twin Cities                48
# 4         3.0      The University of Texas at Austin                44
#
#     Unnamed: 3
# 0     MSI_Type
# 1  No MSI Type
# 2     AANAPISI
# 3     AANAPISI
# 4     AANAPISI

# %%
remMIMIC = remMIMIC.iloc[: , 1:]
remMIMIC = remMIMIC.rename(columns=remMIMIC.iloc[0])
remControl = remControl.iloc[: , 1:]
remControl = remControl.rename(columns=remControl.iloc[0])
remMIMIC = remMIMIC.iloc[1: , :]
remControl = remControl.iloc[1: , :]
remMIMIC = remMIMIC.iloc[1: , :]
remControl = remControl.iloc[1: , :]

# %% [markdown]
# #### below is MSI value counts for the control and compare datasets (union of 2020 and 2022) after manual cleaning process

# %%
remMIMIC
# Out:
#                                           Institution isMinority_Union  \
# 2                  University of Washington - Seattle               70
# 3               University of Minnesota - Twin Cities               48
# 4                   The University of Texas at Austin               44
# 5                            Arizona State University               24
# 6                    University of California, Irvine               12
# 7                   University of Illinois at Chicago                8
# 8                  Texas A&M University-Central Texas                8
# 9                    University of Texas at Arlington                6
# 10                        University of Arizona (The)                6
# 11                     Winston-Salem State University                5
# 12        Rutgers, the State University of New Jersey                5
# 13                              University of Houston                4
# 14                   Florida International University                4
# 15                              Loma Linda University                4
# 16                    University of California, Davis                3
# 17                     St. John's University-New York                3
# 18              Louisiana State University-Alexandria                1
# 19                           University of New Mexico                1
# 20  University of Texas Health Science Center at S...                1
# 21            California State University, Northridge                1
# 22                University of California, Riverside                1
# 23        CUNY Borough of Manhattan Community College                1
# 24                      University of Central Florida                1
# 25               University of California, Santa Cruz                1
# 26                           Georgia State University                1
# 27                                  Howard University                1
# 28            University of California, Santa Barbara                1
# 29                                  Howard University                1
#
#           MSI_Type
# 2         AANAPISI
# 3         AANAPISI
# 4         AANAPISI
# 5              HSI
# 6   AANAPISI & HSI
# 7   AANAPISI & HSI
# 8              HSI
# 9              HSI
# 10             HSI
# 11            HBCU
# 12  AANAPISI & HSI
# 13  AANAPISI & HSI
# 14             HSI
# 15        AANAPISI
# 16        AANAPISI
# 17        AANAPISI
# 18          NASNTI
# 19             HSI
# 20             HSI
# 21             HSI
# 22  AANAPISI & HSI
# 23             HSI
# 24             HSI
# 25             HSI
# 26  AANAPISI & PBI
# 27            HBCU
# 28             HSI
# 29            HBCU

# %%
remControl
# Out:
#                                           Institution isMinority_Union  \
# 2                  University of Washington - Seattle               66
# 3               University of Minnesota - Twin Cities               48
# 4                   The University of Texas at Austin               35
# 5                    University of California, Irvine               10
# 6                   University of Illinois at Chicago                7
# 7           University of Connecticut-Hartford Campus                7
# 8                  Texas A&M University-Central Texas                7
# 9                         University of Arizona (The)                6
# 10                   University of Texas at Arlington                6
# 11        Rutgers, the State University of New Jersey                5
# 12                              Loma Linda University                4
# 13                              University of Houston                4
# 14  Pennsylvania State University - Penn State Abi...                4
# 15                   Florida International University                4
# 16                     St. John's University-New York                2
# 17                     Winston-Salem State University                2
# 18                           Arizona State University                2
# 19                    University of California, Davis                2
# 20               University of California, Santa Cruz                1
# 21                                  Howard University                1
# 22                           Georgia State University                1
# 23                University of California, Riverside                1
# 24                      University of Central Florida                1
# 25        CUNY Borough of Manhattan Community College                1
# 26            California State University, Northridge                1
# 27                           University of New Mexico                1
# 28            University of California, Santa Barbara                1
#
#           MSI_Type
# 2         AANAPISI
# 3         AANAPISI
# 4         AANAPISI
# 5   AANAPISI & HSI
# 6   AANAPISI & HSI
# 7         AANAPISI
# 8              HSI
# 9              HSI
# 10             HSI
# 11  AANAPISI & HSI
# 12        AANAPISI
# 13  AANAPISI & HSI
# 14        AANAPISI
# 15             HSI
# 16        AANAPISI
# 17            HBCU
# 18             HSI
# 19        AANAPISI
# 20             HSI
# 21            HBCU
# 22  AANAPISI & PBI
# 23  AANAPISI & HSI
# 24             HSI
# 25             HSI
# 26             HSI
# 27             HSI
# 28             HSI

# %%
#removing the authors and their corresoponding data if they are not affiliated with a MSI
#the following datasets are outputs of the previous MSI identification pipline
mimic20 = mimic20[mimic20.Type2020 != "Not Minority"]
mimic22 = mimic22[mimic22.Type2022 != "Not Minority"]
control20 = control20[control20.Type2020 != "Not Minority"]
control22 = control22[control22.Type2022 != "Not Minority"]

# %%
mimic20
# Out:
#       Unnamed: 0.1  Unnamed: 0      aff_city  aff_city_id    aff_country  \
# 4              230         230         Tempe    5317058.0  United States
# 77             704         704         Davis    5341704.0  United States
# 78             707         707       Chicago    4887398.0  United States
# 161           1162        1162       Lubbock    5525577.0  United States
# 204           1611        1611        Irvine    5359777.0  United States
# ...            ...         ...           ...          ...            ...
# 3563         13803       13803       Seattle    5809844.0  United States
# 3595         13862       13862       Seattle    5809844.0  United States
# 3596         13864       13864       Seattle    5809844.0  United States
# 3597         13865       13865       Seattle    5809844.0  United States
# 3669         13963       13963  Fort Collins    5577147.0  United States
#
#      aff_country_code         aff_id                           aff_name  \
# 4                  US  grid.215654.1           Arizona State University
# 77                 US  grid.27860.3b    University of California, Davis
# 78                 US  grid.185648.6  University of Illinois at Chicago
# 161                US  grid.264784.b              Texas Tech University
# 204                US  grid.266093.8   University of California, Irvine
# ...               ...            ...                                ...
# 3563               US  grid.34477.33           University of Washington
# 3595               US  grid.34477.33           University of Washington
# 3596               US  grid.34477.33           University of Washington
# 3597               US  grid.34477.33           University of Washington
# 3669               US  grid.47894.36          Colorado State University
#
#                                     aff_raw_affiliation   aff_state  ...  \
# 4     Fulton Schools of Engineering, Arizona State U...     Arizona  ...
# 77    IFM Lab, Department of Computer Science, Unive...  California  ...
# 78    Computer Science Department, University of Ill...    Illinois  ...
# 161   Department of computer science, Texas Tech Uni...       Texas  ...
# 204                     University of California Irvine  California  ...
# ...                                                 ...         ...  ...
# 3563  Department of Epidemiology, University of Wash...  Washington  ...
# 3595  Institute for health metrics and evaluation, U...  Washington  ...
# 3596  Institute for health metrics and evaluation, U...  Washington  ...
# 3597  Institute for health metrics and evaluation, U...  Washington  ...
# 3669  Department of Microbiology, Immunology and Pat...    Colorado  ...
#
#       gender gender_ints income_class income_class_num  \
# 4       male         0.0  High income              4.0
# 77      male         0.0  High income              4.0
# 78      male         0.0  High income              4.0
# 161     male         0.0  High income              4.0
# 204     male         0.0  High income              4.0
# ...      ...         ...          ...              ...
# 3563    male         0.0  High income              4.0
# 3595  female         1.0  High income              4.0
# 3596  female         1.0  High income              4.0
# 3597    male         0.0  High income              4.0
# 3669    male         0.0  High income              4.0
#
#                          isMinority_2020  \
# 4               Arizona State University
# 77       University of California, Davis
# 78     University of Illinois at Chicago
# 161                Texas Tech University
# 204     University of California, Irvine
# ...                                  ...
# 3563  University of Washington - Seattle
# 3595  University of Washington - Seattle
# 3596  University of Washington - Seattle
# 3597  University of Washington - Seattle
# 3669  Colorado State University - Pueblo
#
#                              isMinority_2022 Type2020      Type2022  \
# 4                               Not Minority  Pub 4yr  Not Minority
# 77                              Not Minority  Pub 4yr  Not Minority
# 78                              Not Minority  Pub 4yr  Not Minority
# 161                    Texas Tech University  Pub 4yr    Public 4yr
# 204                             Not Minority  Pub 4yr  Not Minority
# ...                                      ...      ...           ...
# 3563  University of Washington-Tacoma Campus  Pub 4yr    Public 4yr
# 3595  University of Washington-Tacoma Campus  Pub 4yr    Public 4yr
# 3596  University of Washington-Tacoma Campus  Pub 4yr    Public 4yr
# 3597  University of Washington-Tacoma Campus  Pub 4yr    Public 4yr
# 3669        Colorado State University Pueblo  Pub 4yr    Public 4yr
#
#         MSI Type2020  MSI Type2022
# 4                HSI  Not Minority
# 77          AANAPISI  Not Minority
# 78    AANAPISI & HSI  Not Minority
# 161              HSI           HSI
# 204   AANAPISI & HSI  Not Minority
# ...              ...           ...
# 3563        AANAPISI      AANAPISI
# 3595        AANAPISI      AANAPISI
# 3596        AANAPISI      AANAPISI
# 3597        AANAPISI      AANAPISI
# 3669             HSI           HSI
#
# [300 rows x 26 columns]

# %%
mimic22
# Out:
#       Unnamed: 0.1  Unnamed: 0       aff_city  aff_city_id    aff_country  \
# 100            969         969      Nashville    4644585.0  United States
# 161           1162        1162        Lubbock    5525577.0  United States
# 259           1817        1817  Winston-Salem    4499612.0  United States
# 260           1818        1818  Winston-Salem    4499612.0  United States
# 261           1819        1819  Winston-Salem    4499612.0  United States
# ...            ...         ...            ...          ...            ...
# 3563         13803       13803        Seattle    5809844.0  United States
# 3595         13862       13862        Seattle    5809844.0  United States
# 3596         13864       13864        Seattle    5809844.0  United States
# 3597         13865       13865        Seattle    5809844.0  United States
# 3669         13963       13963   Fort Collins    5577147.0  United States
#
#      aff_country_code         aff_id                        aff_name  \
# 100                US  grid.259870.1         Meharry Medical College
# 161                US  grid.264784.b           Texas Tech University
# 259                US  grid.268294.3  Winston-Salem State University
# 260                US  grid.268294.3  Winston-Salem State University
# 261                US  grid.268294.3  Winston-Salem State University
# ...               ...            ...                             ...
# 3563               US  grid.34477.33        University of Washington
# 3595               US  grid.34477.33        University of Washington
# 3596               US  grid.34477.33        University of Washington
# 3597               US  grid.34477.33        University of Washington
# 3669               US  grid.47894.36       Colorado State University
#
#                                     aff_raw_affiliation       aff_state  ...  \
# 100   Department of Computer Science and Data Scienc...       Tennessee  ...
# 161   Department of computer science, Texas Tech Uni...           Texas  ...
# 259   Department of Computer Science, Winston-Salem ...  North Carolina  ...
# 260   Department of Computer Science, Winston-Salem ...  North Carolina  ...
# 261   Center for Applied Data Science (CADS), Winsto...  North Carolina  ...
# ...                                                 ...             ...  ...
# 3563  Department of Epidemiology, University of Wash...      Washington  ...
# 3595  Institute for health metrics and evaluation, U...      Washington  ...
# 3596  Institute for health metrics and evaluation, U...      Washington  ...
# 3597  Institute for health metrics and evaluation, U...      Washington  ...
# 3669  Department of Microbiology, Immunology and Pat...        Colorado  ...
#
#       gender gender_ints income_class income_class_num  \
# 100     male         0.0  High income              4.0
# 161     male         0.0  High income              4.0
# 259     male         0.0  High income              4.0
# 260      NaN         NaN  High income              4.0
# 261      NaN         NaN  High income              4.0
# ...      ...         ...          ...              ...
# 3563    male         0.0  High income              4.0
# 3595  female         1.0  High income              4.0
# 3596  female         1.0  High income              4.0
# 3597    male         0.0  High income              4.0
# 3669    male         0.0  High income              4.0
#
#                          isMinority_2020  \
# 100                         Not Minority
# 161                Texas Tech University
# 259       Winston-Salem State University
# 260       Winston-Salem State University
# 261       Winston-Salem State University
# ...                                  ...
# 3563  University of Washington - Seattle
# 3595  University of Washington - Seattle
# 3596  University of Washington - Seattle
# 3597  University of Washington - Seattle
# 3669  Colorado State University - Pueblo
#
#                              isMinority_2022      Type2020     Type2022  \
# 100                  Meharry Medical College  Not Minority  Private 4yr
# 161                    Texas Tech University       Pub 4yr   Public 4yr
# 259           Winston-Salem State University       Pub 4yr   Public 4yr
# 260           Winston-Salem State University       Pub 4yr   Public 4yr
# 261           Winston-Salem State University       Pub 4yr   Public 4yr
# ...                                      ...           ...          ...
# 3563  University of Washington-Tacoma Campus       Pub 4yr   Public 4yr
# 3595  University of Washington-Tacoma Campus       Pub 4yr   Public 4yr
# 3596  University of Washington-Tacoma Campus       Pub 4yr   Public 4yr
# 3597  University of Washington-Tacoma Campus       Pub 4yr   Public 4yr
# 3669        Colorado State University Pueblo       Pub 4yr   Public 4yr
#
#       MSI Type2020  MSI Type2022
# 100   Not Minority          HBCU
# 161            HSI           HSI
# 259           HBCU          HBCU
# 260           HBCU          HBCU
# 261           HBCU          HBCU
# ...            ...           ...
# 3563      AANAPISI      AANAPISI
# 3595      AANAPISI      AANAPISI
# 3596      AANAPISI      AANAPISI
# 3597      AANAPISI      AANAPISI
# 3669           HSI           HSI
#
# [293 rows x 26 columns]

# %%
control20
# Out:
#       Unnamed: 0.1  Unnamed: 0      aff_city  aff_city_id    aff_country  \
# 18             158         277        Tucson    5318313.0  United States
# 19             159         278        Tucson    5318313.0  United States
# 20             160         279        Tucson    5318313.0  United States
# 21             161         280        Tucson    5318313.0  United States
# 22             162         281        Tucson    5318313.0  United States
# ...            ...         ...           ...          ...            ...
# 7624         25602        3560  Philadelphia    4560349.0  United States
# 7627         25607        3565  Philadelphia    4560349.0  United States
# 7630         25612        3570  Philadelphia    4560349.0  United States
# 7633         25617        3575  Philadelphia    4560349.0  United States
# 7636         25622        3580  Philadelphia    4560349.0  United States
#
#      aff_country_code         aff_id                    aff_name  \
# 18                 US  grid.134563.6       University of Arizona
# 19                 US  grid.134563.6       University of Arizona
# 20                 US  grid.134563.6       University of Arizona
# 21                 US  grid.134563.6       University of Arizona
# 22                 US  grid.134563.6       University of Arizona
# ...               ...            ...                         ...
# 7624               US  grid.25879.31  University of Pennsylvania
# 7627               US  grid.25879.31  University of Pennsylvania
# 7630               US  grid.25879.31  University of Pennsylvania
# 7633               US  grid.25879.31  University of Pennsylvania
# 7636               US  grid.25879.31  University of Pennsylvania
#
#                                     aff_raw_affiliation     aff_state  ...  \
# 18    Department of Surgery, University of Arizona, ...       Arizona  ...
# 19    Program in Applied Mathematics, University of ...       Arizona  ...
# 20    Program in Applied Mathematics, University of ...       Arizona  ...
# 21    Program in Applied Mathematics, University of ...       Arizona  ...
# 22    Program in Applied Mathematics, University of ...       Arizona  ...
# ...                                                 ...           ...  ...
# 7624  Authors' Affiliations: 1Division of Oncology a...  Pennsylvania  ...
# 7627  Authors' Affiliations: 1Division of Oncology a...  Pennsylvania  ...
# 7630  Authors' Affiliations: 1Division of Oncology a...  Pennsylvania  ...
# 7633  Authors' Affiliations: 1Division of Oncology a...  Pennsylvania  ...
# 7636  Authors' Affiliations: 1Division of Oncology a...  Pennsylvania  ...
#
#       gender gender_ints income_class income_class_num  \
# 18    female         1.0  High income              4.0
# 19    female         1.0  High income              4.0
# 20      male         0.0  High income              4.0
# 21    female         1.0  High income              4.0
# 22    female         1.0  High income              4.0
# ...      ...         ...          ...              ...
# 7624  female         1.0  High income              4.0
# 7627    male         0.0  High income              4.0
# 7630    male         0.0  High income              4.0
# 7633    male         0.0  High income              4.0
# 7636    male         0.0  High income              4.0
#
#                          isMinority_2020                     isMinority_2022  \
# 18           University of Arizona (The)               University of Arizona
# 19           University of Arizona (The)               University of Arizona
# 20           University of Arizona (The)               University of Arizona
# 21           University of Arizona (The)               University of Arizona
# 22           University of Arizona (The)               University of Arizona
# ...                                  ...                                 ...
# 7624  Cheyney University of Pennsylvania  Cheyney University of Pennsylvania
# 7627  Cheyney University of Pennsylvania  Cheyney University of Pennsylvania
# 7630  Cheyney University of Pennsylvania  Cheyney University of Pennsylvania
# 7633  Cheyney University of Pennsylvania  Cheyney University of Pennsylvania
# 7636  Cheyney University of Pennsylvania  Cheyney University of Pennsylvania
#
#      Type2020    Type2022 MSI Type2020  MSI Type2022
# 18    Pub 4yr  Public 4yr          HSI           HSI
# 19    Pub 4yr  Public 4yr          HSI           HSI
# 20    Pub 4yr  Public 4yr          HSI           HSI
# 21    Pub 4yr  Public 4yr          HSI           HSI
# 22    Pub 4yr  Public 4yr          HSI           HSI
# ...       ...         ...          ...           ...
# 7624  Pub 4yr  Public 4yr         HBCU          HBCU
# 7627  Pub 4yr  Public 4yr         HBCU          HBCU
# 7630  Pub 4yr  Public 4yr         HBCU          HBCU
# 7633  Pub 4yr  Public 4yr         HBCU          HBCU
# 7636  Pub 4yr  Public 4yr         HBCU          HBCU
#
# [623 rows x 26 columns]

# %%
control22
# Out:
#       Unnamed: 0.1  Unnamed: 0      aff_city  aff_city_id    aff_country  \
# 18             158         277        Tucson    5318313.0  United States
# 19             159         278        Tucson    5318313.0  United States
# 20             160         279        Tucson    5318313.0  United States
# 21             161         280        Tucson    5318313.0  United States
# 22             162         281        Tucson    5318313.0  United States
# ...            ...         ...           ...          ...            ...
# 7624         25602        3560  Philadelphia    4560349.0  United States
# 7627         25607        3565  Philadelphia    4560349.0  United States
# 7630         25612        3570  Philadelphia    4560349.0  United States
# 7633         25617        3575  Philadelphia    4560349.0  United States
# 7636         25622        3580  Philadelphia    4560349.0  United States
#
#      aff_country_code         aff_id                    aff_name  \
# 18                 US  grid.134563.6       University of Arizona
# 19                 US  grid.134563.6       University of Arizona
# 20                 US  grid.134563.6       University of Arizona
# 21                 US  grid.134563.6       University of Arizona
# 22                 US  grid.134563.6       University of Arizona
# ...               ...            ...                         ...
# 7624               US  grid.25879.31  University of Pennsylvania
# 7627               US  grid.25879.31  University of Pennsylvania
# 7630               US  grid.25879.31  University of Pennsylvania
# 7633               US  grid.25879.31  University of Pennsylvania
# 7636               US  grid.25879.31  University of Pennsylvania
#
#                                     aff_raw_affiliation     aff_state  ...  \
# 18    Department of Surgery, University of Arizona, ...       Arizona  ...
# 19    Program in Applied Mathematics, University of ...       Arizona  ...
# 20    Program in Applied Mathematics, University of ...       Arizona  ...
# 21    Program in Applied Mathematics, University of ...       Arizona  ...
# 22    Program in Applied Mathematics, University of ...       Arizona  ...
# ...                                                 ...           ...  ...
# 7624  Authors' Affiliations: 1Division of Oncology a...  Pennsylvania  ...
# 7627  Authors' Affiliations: 1Division of Oncology a...  Pennsylvania  ...
# 7630  Authors' Affiliations: 1Division of Oncology a...  Pennsylvania  ...
# 7633  Authors' Affiliations: 1Division of Oncology a...  Pennsylvania  ...
# 7636  Authors' Affiliations: 1Division of Oncology a...  Pennsylvania  ...
#
#       gender gender_ints income_class income_class_num  \
# 18    female         1.0  High income              4.0
# 19    female         1.0  High income              4.0
# 20      male         0.0  High income              4.0
# 21    female         1.0  High income              4.0
# 22    female         1.0  High income              4.0
# ...      ...         ...          ...              ...
# 7624  female         1.0  High income              4.0
# 7627    male         0.0  High income              4.0
# 7630    male         0.0  High income              4.0
# 7633    male         0.0  High income              4.0
# 7636    male         0.0  High income              4.0
#
#                          isMinority_2020                     isMinority_2022  \
# 18           University of Arizona (The)               University of Arizona
# 19           University of Arizona (The)               University of Arizona
# 20           University of Arizona (The)               University of Arizona
# 21           University of Arizona (The)               University of Arizona
# 22           University of Arizona (The)               University of Arizona
# ...                                  ...                                 ...
# 7624  Cheyney University of Pennsylvania  Cheyney University of Pennsylvania
# 7627  Cheyney University of Pennsylvania  Cheyney University of Pennsylvania
# 7630  Cheyney University of Pennsylvania  Cheyney University of Pennsylvania
# 7633  Cheyney University of Pennsylvania  Cheyney University of Pennsylvania
# 7636  Cheyney University of Pennsylvania  Cheyney University of Pennsylvania
#
#      Type2020    Type2022 MSI Type2020  MSI Type2022
# 18    Pub 4yr  Public 4yr          HSI           HSI
# 19    Pub 4yr  Public 4yr          HSI           HSI
# 20    Pub 4yr  Public 4yr          HSI           HSI
# 21    Pub 4yr  Public 4yr          HSI           HSI
# 22    Pub 4yr  Public 4yr          HSI           HSI
# ...       ...         ...          ...           ...
# 7624  Pub 4yr  Public 4yr         HBCU          HBCU
# 7627  Pub 4yr  Public 4yr         HBCU          HBCU
# 7630  Pub 4yr  Public 4yr         HBCU          HBCU
# 7633  Pub 4yr  Public 4yr         HBCU          HBCU
# 7636  Pub 4yr  Public 4yr         HBCU          HBCU
#
# [592 rows x 26 columns]

# %% [markdown]
# #### following are the affiliation datasets

# %%
mimicAffils
# Out:
#        Unnamed: 0      aff_city  aff_city_id    aff_country aff_country_code  \
# 0               0     Guangzhou    1809858.0          China               CN
# 1               1     Guangzhou    1809858.0          China               CN
# 2               2     Guangzhou    1809858.0          China               CN
# 3               3     Guangzhou    1809858.0          China               CN
# 4               4     Guangzhou    1809858.0          China               CN
# ...           ...           ...          ...            ...              ...
# 13962       13962       Borstel    2945988.0        Germany               DE
# 13963       13963  Fort Collins    5577147.0  United States               US
# 13964       13964      Brisbane    2174003.0      Australia               AU
# 13965       13965        Galway    2964180.0        Ireland               IE
# 13966       13966      Brisbane    2174003.0      Australia               AU
#
#               aff_id                                       aff_name  \
# 0      grid.412601.0  First Affiliated Hospital of Jinan University
# 1      grid.412601.0  First Affiliated Hospital of Jinan University
# 2      grid.412601.0  First Affiliated Hospital of Jinan University
# 3      grid.412601.0  First Affiliated Hospital of Jinan University
# 4      grid.412601.0  First Affiliated Hospital of Jinan University
# ...              ...                                            ...
# 13962  grid.418187.3  Research Center Borstel - Leibniz Lung Center
# 13963  grid.47894.36                      Colorado State University
# 13964    grid.1022.1                            Griffith University
# 13965    grid.6142.1         National University of Ireland, Galway
# 13966    grid.1022.1                            Griffith University
#
#                                      aff_raw_affiliation   aff_state  \
# 0      Department of Neurology, The First Affiliated ...         NaN
# 1      Department of Neurology, The First Affiliated ...         NaN
# 2      Department of Neurology, The First Affiliated ...         NaN
# 3      Department of Neurology, The First Affiliated ...         NaN
# 4      Department of Clinical Research, The First Aff...         NaN
# ...                                                  ...         ...
# 13962  Division of Structural Biochemistry, Departmen...         NaN
# 13963  Department of Microbiology, Immunology and Pat...    Colorado
# 13964  Institute for Glycomics, Gold Coast Campus, Gr...  Queensland
# 13965  School of Natural Sciences, National Universit...         NaN
# 13966  School of Natural Sciences, National Universit...  Queensland
#
#       aff_state_code          pub_id       researcher_id  first_name  \
# 0                NaN  pub.1154144039  ur.014116573320.23     Xiaxuan
# 1                NaN  pub.1154144039  ur.016241001520.36       Shiqi
# 2                NaN  pub.1154144039  ur.013553641416.27      Yitong
# 3                NaN  pub.1154144039  ur.014351222016.81    Shanyuan
# 4                NaN  pub.1154144039  ur.014227217615.79         Tao
# ...              ...             ...                 ...         ...
# 13962            NaN  pub.1008209435  ur.012014630262.69  Anthony P.
# 13963          US-CO  pub.1008209435  ur.012014630262.69  Anthony P.
# 13964         AU-QLD  pub.1008209435  ur.012014630262.69  Anthony P.
# 13965            NaN  pub.1008209435  ur.012014630262.69  Anthony P.
# 13966         AU-QLD  pub.1008209435  ur.012014630262.69  Anthony P.
#
#       last_name  year  gender  gender_ints         income_class  \
# 0         Huang  2022    male          0.0  Upper middle income
# 1          Yuan  2022  female          1.0  Upper middle income
# 2          Ling  2022  female          1.0  Upper middle income
# 3           Tan  2022  female          1.0  Upper middle income
# 4         Huang  2022    male          0.0  Upper middle income
# ...         ...   ...     ...          ...                  ...
# 13962     Moran  2010    male          0.0          High income
# 13963     Moran  2010    male          0.0          High income
# 13964     Moran  2010    male          0.0          High income
# 13965     Moran  2010    male          0.0          High income
# 13966     Moran  2010    male          0.0          High income
#
#        income_class_num
# 0                   3.0
# 1                   3.0
# 2                   3.0
# 3                   3.0
# 4                   3.0
# ...                 ...
# 13962               4.0
# 13963               4.0
# 13964               4.0
# 13965               4.0
# 13966               4.0
#
# [13967 rows x 19 columns]

# %%
controlAffils
# Out:
#        Unnamed: 0   aff_city  aff_city_id  aff_country aff_country_code  \
# 0               6     Leuven    2792482.0      Belgium               BE
# 1               7     Leuven    2792482.0      Belgium               BE
# 2               8     Leuven    2792482.0      Belgium               BE
# 3               9     Leuven    2792482.0      Belgium               BE
# 4              10     Leuven    2792482.0      Belgium               BE
# ...           ...        ...          ...          ...              ...
# 25671        3629  Amsterdam    2759794.0  Netherlands               NL
# 25672        3630  Amsterdam    2759794.0  Netherlands               NL
# 25673        3631  Amsterdam    2759794.0  Netherlands               NL
# 25674        3632   Enschede    2756071.0  Netherlands               NL
# 25675        3633  Amsterdam    2759794.0  Netherlands               NL
#
#               aff_id                                 aff_name  \
# 0      grid.15762.37                                     Imec
# 1      grid.15762.37                                     Imec
# 2      grid.15762.37                                     Imec
# 3                NaN  Independent Consultant, Leuven, Belgium
# 4      grid.15762.37                                     Imec
# ...              ...                                      ...
# 25671    grid.5650.6                  Academic Medical Center
# 25672    grid.5650.6                  Academic Medical Center
# 25673    grid.5650.6                  Academic Medical Center
# 25674    grid.6214.1                     University of Twente
# 25675    grid.5650.6                  Academic Medical Center
#
#                                      aff_raw_affiliation aff_state  \
# 0             Exascience Life Lab, imec, Leuven, Belgium       NaN
# 1             Exascience Life Lab, imec, Leuven, Belgium       NaN
# 2             Exascience Life Lab, imec, Leuven, Belgium       NaN
# 3                Independent Consultant, Leuven, Belgium  Flanders
# 4             Exascience Life Lab, imec, Leuven, Belgium       NaN
# ...                                                  ...       ...
# 25671  Academic Medical Center, Department of Urology...       NaN
# 25672  Academic Medical Center Amsterdam, Department ...       NaN
# 25673  Academic Medical Center, Department of Urology...       NaN
# 25674  University of Twente, MIRA Institute for Biome...       NaN
# 25675  University of Twente, MIRA Institute for Biome...       NaN
#
#       aff_state_code          pub_id       researcher_id        first_name  \
# 0                NaN  pub.1153863516  ur.015256430001.18             Ellie
# 1                NaN  pub.1153863516  ur.010363506743.89         Thomas J.
# 2                NaN  pub.1153863516  ur.012727306525.02              Imen
# 3                NaN  pub.1153863516                 NaN            Thomas
# 4                NaN  pub.1153863516  ur.012704525025.77              Roel
# ...              ...             ...                 ...               ...
# 25671            NaN  pub.1024393212  ur.011026565017.96           Theo M.
# 25672            NaN  pub.1024393212   ur.01015326152.89              Mike
# 25673            NaN  pub.1024393212  ur.015161315017.52  Jean J. M. C. H.
# 25674            NaN  pub.1024393212   ur.01052046002.44            Ton G.
# 25675            NaN  pub.1024393212   ur.01052046002.44            Ton G.
#
#            last_name  year  gender  gender_ints income_class  income_class_num
# 0            D’Hondt  2022  female          1.0  High income               4.0
# 1              Ashby  2022    male          0.0  High income               4.0
# 2           Chakroun  2022  female          1.0  High income               4.0
# 3           Koninckx  2022    male          0.0  High income               4.0
# 4              Wuyts  2022    male          0.0  High income               4.0
# ...              ...   ...     ...          ...          ...               ...
# 25671      de Reijke  2010    male          0.0  High income               4.0
# 25672         Visser  2010    male          0.0  High income               4.0
# 25673  de la Rosette  2010    male          0.0  High income               4.0
# 25674    van Leeuwen  2010    male          0.0  High income               4.0
# 25675    van Leeuwen  2010    male          0.0  High income               4.0
#
# [25676 rows x 19 columns]

# %% [markdown]
# #### the following is used to find which insititutions are affiliated MSIs (after cleaning)

# %%
mimicList = remMIMIC.Institution.values.tolist()

# %%
controlList = remControl.Institution.values.tolist()

# %%
mimInsti = mimic20.loc[mimic20['isMinority_2020'].isin(mimicList)]

# %%
mimInsti
# Out:
#       Unnamed: 0.1  Unnamed: 0 aff_city  aff_city_id    aff_country  \
# 4              230         230    Tempe    5317058.0  United States
# 77             704         704    Davis    5341704.0  United States
# 78             707         707  Chicago    4887398.0  United States
# 204           1611        1611   Irvine    5359777.0  United States
# 207           1614        1614   Irvine    5359777.0  United States
# ...            ...         ...      ...          ...            ...
# 3562         13802       13802  Seattle    5809844.0  United States
# 3563         13803       13803  Seattle    5809844.0  United States
# 3595         13862       13862  Seattle    5809844.0  United States
# 3596         13864       13864  Seattle    5809844.0  United States
# 3597         13865       13865  Seattle    5809844.0  United States
#
#      aff_country_code         aff_id                           aff_name  \
# 4                  US  grid.215654.1           Arizona State University
# 77                 US  grid.27860.3b    University of California, Davis
# 78                 US  grid.185648.6  University of Illinois at Chicago
# 204                US  grid.266093.8   University of California, Irvine
# 207                US  grid.266093.8   University of California, Irvine
# ...               ...            ...                                ...
# 3562               US  grid.34477.33           University of Washington
# 3563               US  grid.34477.33           University of Washington
# 3595               US  grid.34477.33           University of Washington
# 3596               US  grid.34477.33           University of Washington
# 3597               US  grid.34477.33           University of Washington
#
#                                     aff_raw_affiliation   aff_state  ...  \
# 4     Fulton Schools of Engineering, Arizona State U...     Arizona  ...
# 77    IFM Lab, Department of Computer Science, Unive...  California  ...
# 78    Computer Science Department, University of Ill...    Illinois  ...
# 204                     University of California Irvine  California  ...
# 207                    University of California, Irvine  California  ...
# ...                                                 ...         ...  ...
# 3562  Department of Epidemiology, University of Wash...  Washington  ...
# 3563  Department of Epidemiology, University of Wash...  Washington  ...
# 3595  Institute for health metrics and evaluation, U...  Washington  ...
# 3596  Institute for health metrics and evaluation, U...  Washington  ...
# 3597  Institute for health metrics and evaluation, U...  Washington  ...
#
#       gender gender_ints income_class income_class_num  \
# 4       male         0.0  High income              4.0
# 77      male         0.0  High income              4.0
# 78      male         0.0  High income              4.0
# 204     male         0.0  High income              4.0
# 207     male         0.0  High income              4.0
# ...      ...         ...          ...              ...
# 3562    male         0.0  High income              4.0
# 3563    male         0.0  High income              4.0
# 3595  female         1.0  High income              4.0
# 3596  female         1.0  High income              4.0
# 3597    male         0.0  High income              4.0
#
#                          isMinority_2020  \
# 4               Arizona State University
# 77       University of California, Davis
# 78     University of Illinois at Chicago
# 204     University of California, Irvine
# 207     University of California, Irvine
# ...                                  ...
# 3562  University of Washington - Seattle
# 3563  University of Washington - Seattle
# 3595  University of Washington - Seattle
# 3596  University of Washington - Seattle
# 3597  University of Washington - Seattle
#
#                              isMinority_2022 Type2020      Type2022  \
# 4                               Not Minority  Pub 4yr  Not Minority
# 77                              Not Minority  Pub 4yr  Not Minority
# 78                              Not Minority  Pub 4yr  Not Minority
# 204                             Not Minority  Pub 4yr  Not Minority
# 207                             Not Minority  Pub 4yr  Not Minority
# ...                                      ...      ...           ...
# 3562  University of Washington-Tacoma Campus  Pub 4yr    Public 4yr
# 3563  University of Washington-Tacoma Campus  Pub 4yr    Public 4yr
# 3595  University of Washington-Tacoma Campus  Pub 4yr    Public 4yr
# 3596  University of Washington-Tacoma Campus  Pub 4yr    Public 4yr
# 3597  University of Washington-Tacoma Campus  Pub 4yr    Public 4yr
#
#         MSI Type2020  MSI Type2022
# 4                HSI  Not Minority
# 77          AANAPISI  Not Minority
# 78    AANAPISI & HSI  Not Minority
# 204   AANAPISI & HSI  Not Minority
# 207   AANAPISI & HSI  Not Minority
# ...              ...           ...
# 3562        AANAPISI      AANAPISI
# 3563        AANAPISI      AANAPISI
# 3595        AANAPISI      AANAPISI
# 3596        AANAPISI      AANAPISI
# 3597        AANAPISI      AANAPISI
#
# [198 rows x 26 columns]

# %%
mimInsti2 = mimic22.loc[mimic22['isMinority_2022'].isin(mimicList)]

# %%
mimInsti2
# Out:
#       Unnamed: 0.1  Unnamed: 0         aff_city  aff_city_id    aff_country  \
# 259           1817        1817    Winston-Salem    4499612.0  United States
# 260           1818        1818    Winston-Salem    4499612.0  United States
# 261           1819        1819    Winston-Salem    4499612.0  United States
# 383           2502        2502           Austin    4671654.0  United States
# 384           2503        2503           Austin    4671654.0  United States
# ...            ...         ...              ...          ...            ...
# 3017         12763       12763            Miami    4164138.0  United States
# 3018         12764       12764            Miami    4164138.0  United States
# 3019         12765       12765            Miami    4164138.0  United States
# 3020         12766       12766            Miami    4164138.0  United States
# 3192         13217       13217  Washington D.C.    4140963.0  United States
#
#      aff_country_code         aff_id                           aff_name  \
# 259                US  grid.268294.3     Winston-Salem State University
# 260                US  grid.268294.3     Winston-Salem State University
# 261                US  grid.268294.3     Winston-Salem State University
# 383                US  grid.89336.37  The University of Texas at Austin
# 384                US  grid.89336.37  The University of Texas at Austin
# ...               ...            ...                                ...
# 3017               US  grid.65456.34   Florida International University
# 3018               US  grid.65456.34   Florida International University
# 3019               US  grid.65456.34   Florida International University
# 3020               US  grid.65456.34   Florida International University
# 3192               US  grid.257127.4                  Howard University
#
#                                     aff_raw_affiliation             aff_state  \
# 259   Department of Computer Science, Winston-Salem ...        North Carolina
# 260   Department of Computer Science, Winston-Salem ...        North Carolina
# 261   Center for Applied Data Science (CADS), Winsto...        North Carolina
# 383   The University of Texas at Austin, Austin, TX,...                 Texas
# 384   The University of Texas at Austin, Austin, TX,...                 Texas
# ...                                                 ...                   ...
# 3017  Department of Electrical and Computer Engineer...               Florida
# 3018  School of Computing and Information Sciences, ...               Florida
# 3019  School of Computing and Information Sciences, ...               Florida
# 3020  School of Computing and Information Sciences, ...               Florida
# 3192  Department of Anatomy, Howard University Colle...  District of Columbia
#
#       ...  gender gender_ints income_class income_class_num  \
# 259   ...    male         0.0  High income              4.0
# 260   ...     NaN         NaN  High income              4.0
# 261   ...     NaN         NaN  High income              4.0
# 383   ...    male         0.0  High income              4.0
# 384   ...    male         0.0  High income              4.0
# ...   ...     ...         ...          ...              ...
# 3017  ...  female         1.0  High income              4.0
# 3018  ...  female         1.0  High income              4.0
# 3019  ...  female         1.0  High income              4.0
# 3020  ...    male         0.0  High income              4.0
# 3192  ...  female         1.0  High income              4.0
#
#                        isMinority_2020                    isMinority_2022  \
# 259     Winston-Salem State University     Winston-Salem State University
# 260     Winston-Salem State University     Winston-Salem State University
# 261     Winston-Salem State University     Winston-Salem State University
# 383                       Not Minority  The University of Texas at Austin
# 384                       Not Minority  The University of Texas at Austin
# ...                                ...                                ...
# 3017  Florida International University   Florida International University
# 3018  Florida International University   Florida International University
# 3019  Florida International University   Florida International University
# 3020  Florida International University   Florida International University
# 3192                 Howard University                  Howard University
#
#           Type2020     Type2022  MSI Type2020  MSI Type2022
# 259        Pub 4yr   Public 4yr          HBCU          HBCU
# 260        Pub 4yr   Public 4yr          HBCU          HBCU
# 261        Pub 4yr   Public 4yr          HBCU          HBCU
# 383   Not Minority   Public 4yr  Not Minority      AANAPISI
# 384   Not Minority   Public 4yr  Not Minority      AANAPISI
# ...            ...          ...           ...           ...
# 3017       Pub 4yr   Public 4yr           HSI           HSI
# 3018       Pub 4yr   Public 4yr           HSI           HSI
# 3019       Pub 4yr   Public 4yr           HSI           HSI
# 3020       Pub 4yr   Public 4yr           HSI           HSI
# 3192       Pri 4yr  Private 4yr          HBCU          HBCU
#
# [77 rows x 26 columns]

# %%
controlInsti = control20.loc[control20['isMinority_2020'].isin(controlList)]

# %%
controlInsti
# Out:
#       Unnamed: 0.1  Unnamed: 0     aff_city  aff_city_id    aff_country  \
# 18             158         277       Tucson    5318313.0  United States
# 19             159         278       Tucson    5318313.0  United States
# 20             160         279       Tucson    5318313.0  United States
# 21             161         280       Tucson    5318313.0  United States
# 22             162         281       Tucson    5318313.0  United States
# ...            ...         ...          ...          ...            ...
# 7546         25231        3189  Minneapolis    5037649.0  United States
# 7547         25232        3190  Minneapolis    5037649.0  United States
# 7548         25233        3191  Minneapolis    5037649.0  United States
# 7550         25235        3193  Minneapolis    5037649.0  United States
# 7551         25236        3194  Minneapolis    5037649.0  United States
#
#      aff_country_code         aff_id                 aff_name  \
# 18                 US  grid.134563.6    University of Arizona
# 19                 US  grid.134563.6    University of Arizona
# 20                 US  grid.134563.6    University of Arizona
# 21                 US  grid.134563.6    University of Arizona
# 22                 US  grid.134563.6    University of Arizona
# ...               ...            ...                      ...
# 7546               US  grid.17635.36  University of Minnesota
# 7547               US  grid.17635.36  University of Minnesota
# 7548               US  grid.17635.36  University of Minnesota
# 7550               US  grid.17635.36  University of Minnesota
# 7551               US  grid.17635.36  University of Minnesota
#
#                                     aff_raw_affiliation  aff_state  ...  \
# 18    Department of Surgery, University of Arizona, ...    Arizona  ...
# 19    Program in Applied Mathematics, University of ...    Arizona  ...
# 20    Program in Applied Mathematics, University of ...    Arizona  ...
# 21    Program in Applied Mathematics, University of ...    Arizona  ...
# 22    Program in Applied Mathematics, University of ...    Arizona  ...
# ...                                                 ...        ...  ...
# 7546  The Hormel Institute, University of Minnesota,...  Minnesota  ...
# 7547  The Hormel Institute, University of Minnesota,...  Minnesota  ...
# 7548  The Hormel Institute, University of Minnesota,...  Minnesota  ...
# 7550  The Hormel Institute, University of Minnesota,...  Minnesota  ...
# 7551  The Hormel Institute, University of Minnesota,...  Minnesota  ...
#
#       gender gender_ints income_class income_class_num  \
# 18    female         1.0  High income              4.0
# 19    female         1.0  High income              4.0
# 20      male         0.0  High income              4.0
# 21    female         1.0  High income              4.0
# 22    female         1.0  High income              4.0
# ...      ...         ...          ...              ...
# 7546    male         0.0  High income              4.0
# 7547    male         0.0  High income              4.0
# 7548  female         1.0  High income              4.0
# 7550  female         1.0  High income              4.0
# 7551    male         0.0  High income              4.0
#
#                             isMinority_2020                 isMinority_2022  \
# 18              University of Arizona (The)           University of Arizona
# 19              University of Arizona (The)           University of Arizona
# 20              University of Arizona (The)           University of Arizona
# 21              University of Arizona (The)           University of Arizona
# 22              University of Arizona (The)           University of Arizona
# ...                                     ...                             ...
# 7546  University of Minnesota - Twin Cities  University of Minnesota-Morris
# 7547  University of Minnesota - Twin Cities  University of Minnesota-Morris
# 7548  University of Minnesota - Twin Cities  University of Minnesota-Morris
# 7550  University of Minnesota - Twin Cities  University of Minnesota-Morris
# 7551  University of Minnesota - Twin Cities  University of Minnesota-Morris
#
#      Type2020    Type2022 MSI Type2020  MSI Type2022
# 18    Pub 4yr  Public 4yr          HSI           HSI
# 19    Pub 4yr  Public 4yr          HSI           HSI
# 20    Pub 4yr  Public 4yr          HSI           HSI
# 21    Pub 4yr  Public 4yr          HSI           HSI
# 22    Pub 4yr  Public 4yr          HSI           HSI
# ...       ...         ...          ...           ...
# 7546  Pub 4yr  Public 4yr     AANAPISI        NASNTI
# 7547  Pub 4yr  Public 4yr     AANAPISI        NASNTI
# 7548  Pub 4yr  Public 4yr     AANAPISI        NASNTI
# 7550  Pub 4yr  Public 4yr     AANAPISI        NASNTI
# 7551  Pub 4yr  Public 4yr     AANAPISI        NASNTI
#
# [288 rows x 26 columns]

# %%
controlInsti2 = control22.loc[control22['isMinority_2022'].isin(controlList)]

# %%
controlInsti2
# Out:
#       Unnamed: 0.1  Unnamed: 0    aff_city  aff_city_id    aff_country  \
# 694           2726        3224  Loma Linda    5367696.0  United States
# 805           3043        3541  Loma Linda    5367696.0  United States
# 832           3155        3653     Orlando    4167147.0  United States
# 1797          6437        2921    New York    5128581.0  United States
# 2319          8411         902      Austin    4671654.0  United States
# ...            ...         ...         ...          ...            ...
# 7525         25026        2984      Storrs    4843786.0  United States
# 7526         25027        2985      Storrs    4843786.0  United States
# 7584         25541        3499      Austin    4671654.0  United States
# 7585         25542        3500      Austin    4671654.0  United States
# 7588         25545        3503      Austin    4671654.0  United States
#
#      aff_country_code         aff_id                              aff_name  \
# 694                US  grid.411390.e  Loma Linda University Medical Center
# 805                US  grid.411390.e  Loma Linda University Medical Center
# 832                US  grid.170430.1         University of Central Florida
# 1797               US  grid.264091.8                 St. John's University
# 2319               US  grid.89336.37     The University of Texas at Austin
# ...               ...            ...                                   ...
# 7525               US  grid.63054.34             University of Connecticut
# 7526               US  grid.63054.34             University of Connecticut
# 7584               US  grid.89336.37     The University of Texas at Austin
# 7585               US  grid.89336.37     The University of Texas at Austin
# 7588               US  grid.89336.37     The University of Texas at Austin
#
#                                     aff_raw_affiliation    aff_state  ...  \
# 694   Faculty of School of Medicine, Loma Linda Univ...   California  ...
# 805   Department of Anesthesiology, Loma Linda Unive...   California  ...
# 832   UCF College of Medicine, 6850 Lake Nona Blvd, ...      Florida  ...
# 1797  From the Department of Pathology (F.S.A.), Yal...     New York  ...
# 2319  Department of Biomedical Engineering, The Univ...        Texas  ...
# ...                                                 ...          ...  ...
# 7525  Department of Computer Science & Engineering, ...  Connecticut  ...
# 7526  Department of Computer Science & Engineering, ...  Connecticut  ...
# 7584  Institute of Cellular and Molecular Biology, D...        Texas  ...
# 7585  Institute of Cellular and Molecular Biology, D...        Texas  ...
# 7588  Institute of Cellular and Molecular Biology, D...        Texas  ...
#
#       gender gender_ints income_class income_class_num  \
# 694     male         0.0  High income              4.0
# 805     male         0.0  High income              4.0
# 832     male         0.0  High income              4.0
# 1797    male         0.0  High income              4.0
# 2319     NaN         NaN  High income              4.0
# ...      ...         ...          ...              ...
# 7525    male         0.0  High income              4.0
# 7526     NaN         NaN  High income              4.0
# 7584    male         0.0  High income              4.0
# 7585  female         1.0  High income              4.0
# 7588    male         0.0  High income              4.0
#
#                                   isMinority_2020  \
# 694                                  Not Minority
# 805                                  Not Minority
# 832                 University of Central Florida
# 1797                                 Not Minority
# 2319                                 Not Minority
# ...                                           ...
# 7525  University of Connecticut - Hartford Campus
# 7526  University of Connecticut - Hartford Campus
# 7584                                 Not Minority
# 7585                                 Not Minority
# 7588                                 Not Minority
#
#                                 isMinority_2022      Type2020     Type2022  \
# 694                       Loma Linda University  Not Minority  Private 4yr
# 805                       Loma Linda University  Not Minority  Private 4yr
# 832               University of Central Florida       Pub 4yr   Public 4yr
# 1797             St. John's University-New York  Not Minority  Private 4yr
# 2319          The University of Texas at Austin  Not Minority   Public 4yr
# ...                                         ...           ...          ...
# 7525  University of Connecticut-Hartford Campus       Pub 4yr   Public 4yr
# 7526  University of Connecticut-Hartford Campus       Pub 4yr   Public 4yr
# 7584          The University of Texas at Austin  Not Minority   Public 4yr
# 7585          The University of Texas at Austin  Not Minority   Public 4yr
# 7588          The University of Texas at Austin  Not Minority   Public 4yr
#
#       MSI Type2020  MSI Type2022
# 694   Not Minority      AANAPISI
# 805   Not Minority      AANAPISI
# 832            HSI           HSI
# 1797  Not Minority      AANAPISI
# 2319  Not Minority      AANAPISI
# ...            ...           ...
# 7525      AANAPISI      AANAPISI
# 7526      AANAPISI      AANAPISI
# 7584  Not Minority      AANAPISI
# 7585  Not Minority      AANAPISI
# 7588  Not Minority      AANAPISI
#
# [75 rows x 26 columns]

# %%
# concatenating the 2020 and 2022 lists for control and compare
controlMaster = pd.concat([controlInsti, controlInsti2], ignore_index = True)
mimicMaster = pd.concat([mimInsti, mimInsti2], ignore_index = True)

# %%
mimicMaster['full_name'] = mimicMaster[['first_name', 'last_name']].apply(lambda x: ' '.join(x), axis=1)
controlMaster['full_name'] = controlMaster[['first_name', 'last_name']].astype(str).apply(lambda x: ' '.join(x), axis=1)

# %%
#dropping duplicates to find distinct authors affiliated with MSIs
controlMaster = controlMaster.drop_duplicates(subset = 'full_name', keep = 'first')
mimicMaster = mimicMaster.drop_duplicates(subset = 'full_name', keep = 'first')

# %%
mimicMaster['gender'].value_counts()
# Out:
# male      135
# female     35
# Name: gender, dtype: int64

# %%
def isfloat(num):
    try:
        float(num)
        return True
    except ValueError:
        return False

# %%
controlGender['full_name'] = controlGender[['first_name', 'last_name']].astype(str).apply(lambda x: ' '.join(x), axis=1)

# %%
def genderFind (x):
    try:
        gender = controlGender.loc[controlGender['full_name'] == x, 'gender'].iloc[0]
    except IndexError:
        gender = 'None'
    return gender

# %%
controlGender['gender'].dropna()
# Out:
# 0        male
# 1        male
# 2        male
# 3        male
# 4        male
#          ...
# 26820    male
# 26821    male
# 26822    male
# 26823    male
# 26824    male
# Name: gender, Length: 23004, dtype: object

# %%
controlMaster['gender'] = controlMaster['full_name'].apply(genderFind)

# %%
# the control affil dataset I originially used didn't have genders so I used another dataset 
# which had the genders of the authors

controlMaster['gender'].value_counts()
# Out:
# male      163
# female     86
# Name: gender, dtype: int64

# %% [markdown]
# ### Gender Results:
# * MIMIC: 170 authors w/ non missing gender; 135 male; 35 female
# * Control: 249 authors w/ non missing gender; 163 male; 86 female

# %% [markdown]
# # First vs Last Authors Affiliated w/ MSIs

# %%
#list of authors affiliated with MSIs (after manual verification)
mimic = pd.read_csv("/Users/gurucharanlingamallu/Documents/MIT Work/mimicAuthors(d).csv")
control = pd.read_csv("/Users/gurucharanlingamallu/Documents/MIT Work/controlAuthors(d).csv")

#these lists are used to find the author sequence (by research paper) 
conAuth = pd.read_csv("/Users/gurucharanlingamallu/Downloads/control_group_auths_v2.csv")
mimAuth = pd.read_csv("/Users/gurucharanlingamallu/Downloads/mimic_auths_v2.csv")

# %%
mimAuth['authorSeq'] = 'Any'

# %%
conAuth['authorSeq'] = 'Any'

# %%
#adding sequence of authors for control
for i in range(21364):
    if i == 0:
        conAuth.loc[0, 'authorSeq'] = 'First' 
    elif i == 21363:
        conAuth.loc[21363, 'authorSeq'] = 'Last'
    else:
        if(conAuth.loc[i - 1, 'pub_id'] != conAuth.loc[i, 'pub_id']):
            conAuth.loc[i, 'authorSeq'] = 'First'
        elif(conAuth.loc[i + 1, 'pub_id'] != conAuth.loc[i, 'pub_id']):
            conAuth.loc[i, 'authorSeq'] = 'Last'

# %%
#adding sequence of authors for compare
for i in range(13838):
    if i == 0:
        mimAuth.loc[0, 'authorSeq'] = 'First' 
    elif i == 13837:
        mimAuth.loc[13837, 'authorSeq'] = 'First'
    else:
        if(mimAuth.loc[i - 1, 'pub_id'] != mimAuth.loc[i, 'pub_id']):
            mimAuth.loc[i, 'authorSeq'] = 'First'
        elif(mimAuth.loc[i + 1, 'pub_id'] != mimAuth.loc[i, 'pub_id']):
            mimAuth.loc[i, 'authorSeq'] = 'Last'

# %%
#adding rows for full names
#some authors don't have a unique research id associated with them so this allows for a more accurate mapping
conAuth['full_name'] = conAuth[['first_name', 'last_name']].astype(str).apply(lambda x: ' '.join(x), axis=1)
mimAuth['full_name'] = mimAuth[['first_name', 'last_name']].astype(str).apply(lambda x: ' '.join(x), axis=1)

# %%
#function for mapping MSI affiliated authors with their correct position
def authFindC (x):
    try:
        seq = conAuth.loc[conAuth['full_name'] == x, 'authorSeq'].iloc[0]
    except IndexError:
        seq = 'Any'
    return seq

def authFindM (x):
    try:
        seq = mimAuth.loc[mimAuth['full_name'] == x, 'authorSeq'].iloc[0]
    except IndexError:
        seq = 'Any'
    return seq

# %% [markdown]
# ### Results

# %%
control['authorSeq'] = control['full_name'].apply(authFindC)

# %%
control['authorSeq'].value_counts()
# Out:
# Any      182
# Last      56
# First     48
# Name: authorSeq, dtype: int64

# %%
mimic['authorSeq'] = mimic['full_name'].apply(authFindM)

# %%
mimic['authorSeq'].value_counts()
# Out:
# Any      126
# First     36
# Last      28
# Name: authorSeq, dtype: int64

# %% [markdown]
# # T-Tests

# %%
#author affiliation datasets
controlT = pd.read_csv("/Users/gurucharanlingamallu/Downloads/control_group_affils(7).csv", encoding='utf-8')
mimicT = pd.read_csv("/Users/gurucharanlingamallu/Downloads/mimic_affils(7).csv", encoding='utf-8')

# %%
#list of authors affiliated with MSIs and their corresponding information (after manual verification)
mimic = pd.read_csv("/Users/gurucharanlingamallu/Documents/MIT Work/mimicAuthors(d).csv")
control = pd.read_csv("/Users/gurucharanlingamallu/Documents/MIT Work/controlAuthors(d).csv")

# %%
control['full_name'] = control[['first_name', 'last_name']].astype(str).apply(lambda x: ' '.join(x), axis=1)
mimic['full_name'] = mimic[['first_name', 'last_name']].astype(str).apply(lambda x: ' '.join(x), axis=1)

# %%
controlList = control.full_name.values.tolist()

# %%
mimicList = mimic.full_name.values.tolist()

# %%
controlT['full_name'] = controlT[['first_name', 'last_name']].astype(str).apply(lambda x: ' '.join(x), axis=1)

# %%
mimicT['full_name'] = mimicT[['first_name', 'last_name']].astype(str).apply(lambda x: ' '.join(x), axis=1)

# %%
#mapping the list of authors affiliated with MSIs to the overall datasets in order to do t-tests on the entire author population
def isMinCon (x):
    if x in controlList:
        return 1
    else:
        return 0
def isMinMim (x):
    if x in mimicList:
        return 1
    else:
        return 0

# %%
controlT['minority'] = controlT['full_name'].apply(isMinCon)

# %%
mimicT['minority'] = mimicT['full_name'].apply(isMinMim)

# %% [markdown]
# ### T-test for MSI Author Distribution

# %%
from scipy.stats import ttest_ind

def get_ttest_any(df):
    return df.groupby("pub_id").minority.any()

print(f"t-test: minority {ttest_ind(get_ttest_any(mimicT), get_ttest_any(controlT), alternative= 'greater')}")
# Out:
# t-test: minority Ttest_indResult(statistic=5.125750776843266, pvalue=1.5432410937220337e-07)

# %% [markdown]
# ### T-Test for First vs Last Author Distribution

# %%
controlT['authorSeq'] = 'Any'

# %%
mimicT['authorSeq'] = 'Any'

# %%
#adding author sequence to overall datastes
for i in range(mimicT.shape[0]):
    if i == 0:
        mimicT.loc[0, 'authorSeq'] = 'First' 
    elif i == mimicT.shape[0] - 1:
        mimicT.loc[mimicT.shape[0] - 1, 'authorSeq'] = 'First'
    else:
        if(mimicT.loc[i - 1, 'pub_id'] != mimicT.loc[i, 'pub_id']):
            mimicT.loc[i, 'authorSeq'] = 'First'
        elif(mimicT.loc[i + 1, 'pub_id'] != mimicT.loc[i, 'pub_id']):
            mimicT.loc[i, 'authorSeq'] = 'Last'

for i in range(controlT.shape[0]):
    if i == 0:
        controlT.loc[0, 'authorSeq'] = 'First' 
    elif i == controlT.shape[0] - 1:
        controlT.loc[controlT.shape[0] - 1, 'authorSeq'] = 'First'
    else:
        if(controlT.loc[i - 1, 'pub_id'] != controlT.loc[i, 'pub_id']):
            controlT.loc[i, 'authorSeq'] = 'First'
        elif(controlT.loc[i + 1, 'pub_id'] != controlT.loc[i, 'pub_id']):
            controlT.loc[i, 'authorSeq'] = 'Last'

# %%
mimicT['firstSeq'] = (mimicT['minority'] == 1) & (mimicT['authorSeq'] == 'First')
mimicT['firstSeq'] = mimicT['firstSeq'].astype(int)
controlT['firstSeq'] = (controlT['minority'] == 1) & (controlT['authorSeq'] == 'First')
controlT['firstSeq'] = controlT['firstSeq'].astype(int)

# %%
mimicT['lastSeq'] = (mimicT['minority'] == 1) & (mimicT['authorSeq'] == 'Last')
controlT['lastSeq'] = (controlT['minority'] == 1) & (controlT['authorSeq'] == 'Last')
mimicT['lastSeq'] = mimicT['lastSeq'].astype(int)
controlT['lastSeq'] = controlT['lastSeq'].astype(int)

# %%
#first authors
def get_ttest_any2(df):
    return df.groupby("pub_id").firstSeq.any()

print(f"t-test: minority {ttest_ind(get_ttest_any2(mimicT), get_ttest_any2(controlT), alternative= 'greater')}")
# Out:
# t-test: minority Ttest_indResult(statistic=2.969446562475738, pvalue=0.0014994760337273376)

# %%
#last authors
def get_ttest_any3(df):
    return df.groupby("pub_id").lastSeq.any()

print(f"t-test: minority {ttest_ind(get_ttest_any3(mimicT), get_ttest_any3(controlT), alternative= 'greater')}")
# Out:
# t-test: minority Ttest_indResult(statistic=1.7684355004194527, pvalue=0.038527582218135036)

# %% [markdown]
# ### T-Test for Gender Distribution

# %%
controlT['isFemale'] = (controlT['minority'] == 1) & (controlT['gender'] == 'female')
mimicT['isFemale'] = (mimicT['minority'] == 1) & (mimicT['gender'] == 'female')

# %%
def get_ttest_any4(df):
    return df.groupby("pub_id").isFemale.any()

print(f"t-test: minority {ttest_ind(get_ttest_any4(mimicT), get_ttest_any4(controlT), alternative= 'greater')}")
# Out:
# t-test: minority Ttest_indResult(statistic=1.099853909556267, pvalue=0.1357270025390229)
